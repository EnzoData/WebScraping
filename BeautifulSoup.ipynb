# %% [markdown]
# ## Beautiful Soup Tutorial: Install BeautifulSoup, Requests & LXML
# https://python.gotrained.com/install-beautifulsoup/

# %% [markdown]
# To start Web Scraping tutorials, the first thing to do is to install the 3 libraries: BeautifulSoup, Requests, and LXML. We will use PIP. Note that sudo might be required if you are on Linux or Mac.
#
# * pip install beautifulsoup4
# * pip install requests
# * pip install lxml

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Extracting URLs

# %%
url = "http://www.htmlandcssbook.com/code-samples/chapter-04/example.html"
 
# Getting the webpage, creating a Response object.
response = requests.get(url)
 
# Extracting the source code of the page.
data = response.text
 
# Passing the source code to BeautifulSoup to create a BeautifulSoup object for it.
soup = BeautifulSoup(data, 'lxml')
 
# Extracting all the <a> tags into a list.
tags = soup.find_all('a')
 
# Extracting URLs from the attribute href in the <a> tags.
for tag in tags:
    print(tag.get('href'))
# Out:
# mailto:filmfolk@example.org
# http://www.sundance.org
# http://www.tropfest.com
# http://sxsw.com
# http://www.londonindependent.org
# http://www.festival-cannes.com
# http://www.sff.org.au
# http://www.miff.com.au
# http://www.nzff.co.nz
# http://www.labiennale.org/en/cinema
# http://www.bfi.org.uk/lff/
# http://www.idfa.nl/industry.aspx
# http://whistlerfilmfestival.com
# about.html
# #top

# %%
# Using the tutorial to WebScrape data from mlb.com on Sammy Sosa
url = "https://www.mlb.com/player/sammy-sosa-122544"
 
# Getting the webpage, creating a Response object.
response = requests.get(url)
 
# Extracting the source code of the page.
data = response.text
 
# Passing the source code to BeautifulSoup to create a BeautifulSoup object for it.
soup = BeautifulSoup(data, 'lxml')
 
# Extracting all the <a> tags into a list.
tags = soup.find_all('a')
 
# Extracting URLs from the attribute href in the <a> tags.
for tag in tags:
    print(tag.get('href'))
# Out:
# /
# /login?redirectUri=https://www.mlb.com/player/sammy-sosa-122544
# None
# https://www.mlb.com/scores
# https://www.mlb.com/news
# https://www.mlb.com/video
# https://www.mlb.com/standings
# http://mlb.mlb.com/stats/sortable.jsp
# http://mlb.mlb.com/mlb/schedule/index.jsp
# https://www.mlb.com/player-search?tcid=nav_mlb_players
# https://www.mlb.com/live-stream-games/subscribe?&affiliateId=MEGAMENU
# http://mlb.mlb.com/mlb/baseballtickets/
# https://www.mlb.com/apps
# https://www.mlbshop.com/?_s=bm-mlbcom-hp
# https://auctions.mlb.com
# https://www.mlb.com/fantasy
# https://www.playball.org/
# https://www.mlb.com/team
# http://mlb.mlb.com/home
# https://www.mlb.com/scores
# https://www.mlb.com/news
# https://www.mlb.com/probable-pitchers
# http://m.mlb.com/prospects/2019
# http://mlb.mlb.com/mlb/fantasy/injuries/
# http://mlb.mlb.com/mlb/transactions/?tcid=mm_mlb_news
# https://www.mlb.com/starting-lineups
# http://m.mlb.com/hof
# http://m.mlb.com/postseason/history/world-series
# https://www.mlb.com/awards
# /draft/2019
# /all-star
# https://www.mlb.com/cut4
# https://www.mlb.com/news/2019-all-star-game-rosters
# https://www.playball.org/
# /pipeline
# https://www.mlb.com/photos/home
# https://www.mlb.com/news/topic/rare-feats
# /news/topic/beat-reporters-inbox/
# https://www.mlb.com/news/topic/trade-talk-and-rumors
# http://m.mlb.com/glossary
# https://www.mlb.com/video
# https://www.mlb.com/live-stream-games/?&affiliateId=MEGAMENU
# https://www.mlb.com/video/search/tag/condensed-game?displayName=condensed%20game
# https://www.mlb.com/video/topic/daily-recaps
# https://www.mlb.com/video/topic/real-fast
# https://www.mlb.com/video/topic/fastcast
# https://www.mlb.com/video/topic/replay-review
# http://m.mlb.com/gif-download-video-embed-hub
# http://m.mlb.com/network
# http://mlb.mlb.com/mlb/audio/podcast/?tcid=mm_mlb_vid
# https://www.mlb.com/video/topic/business-of-baseball
# https://www.mlb.com/video/topic/must-c
# https://www.mlb.com/video
# https://www.mlb.com/video/topic/home-runs
# https://www.mlb.com/video/topic/walk-offs
# https://www.mlb.com/video/topic/top-defensive-plays
# https://www.mlb.com/video/topic/grand-slams
# https://www.mlb.com/video/topic/statcast
# https://www.mlb.com/video/topic/extra-innings
# https://www.mlb.com/video/topic/chatting-cage
# https://www.mlb.com/video/topic/must-c
# https://www.mlb.com/video/topic/carry-the-freight
# https://www.mlb.com/standings
# https://www.mlb.com/standings
# https://www.mlb.com/standings/spring-training
# https://www.mlb.com/postseason
# https://www.mlb.com/standings/regular-season/2018
# http://mlb.mlb.com/mlb/standings/wildcard.jsp
# https://www.mlb.com/standings/regular-season/2017
# http://mlb.mlb.com/mlb/standings/index.jsp
# http://mlb.mlb.com/stats/sortable.jsp
# http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&tab_level=child&click_text=Sortable+Player+hitting&game_type='R'&season=2019&season_type=ANY&league_code='MLB'&sectionType=sp&statType=hitting&page=1&ts=1521669961941&playerType=QUALIFIER&sportCode='mlb'&split=&team_id=&active_sw=&position=&page_type=SortablePlayer&sortOrder='desc'&sortColumn=avg&results=&perPage=50&timeframe=&last_x_days=&extended=0
# http://mlb.mlb.com/stats/league_leaders.jsp#season=2019
# http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&tab_level=child&click_text=Sortable+Team+hitting&game_type='R'&season=2019&season_type=ANY&league_code='MLB'&statType=hitting&page=1&ts=1491184063696&sectionType=st&playerType=QUALIFIER&sportCode='mlb'&split=&team_id=&active_sw=&position=&page_type=SortablePlayer&sortOrder='desc'&sortColumn=avg&results=&perPage=50&timeframe=&last_x_days=&extended=0
# http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&tab_level=child&click_text=Sortable+Player+hitting&game_type='S'&season=2019&season_type=ANY&league_code='MLB'&sectionType=sp&statType=hitting&page=1&ts=1520018341560&timeframe=&playerType=QUALIFIER&sportCode='mlb'&split=&team_id=&active_sw=&position=&page_type=SortablePlayer&sortOrder='desc'&sortColumn=avg&results=&perPage=50&last_x_days=&extended=0
# http://m.mlb.com/tickets/theme-tickets/autism-awareness
# https://www.mlb.com/tickets/fan-value
# http://mlb.mlb.com/sh
# https://www.mlb.com/tickets/big-league-tours
# https://www.mlb.com/apps
# https://www.mlb.com/apps/atbat
# https://www.mlb.com/apps/ballpark
# https://www.milb.com/about/first-pitch
# http://www.rbigame.com/
# https://www.mlb.com/fantasy/home-run-derby
# https://www.mlb.com/apps/beat-the-streak
# https://www.mlb.com/fantasy/line-drive
# https://www.mlb.com/apps/atbat/faq-apple
# https://www.mlb.com/apps/ballpark/faq-apple
# https://www.mlb.com/apps/atbat
# https://www.mlb.com/apps/ballpark
# http://www.rbigame.com/
# https://www.mlbshop.com/?_s=bm-mlbcom-hp
# https://www.mlbshop.com/jerseys/d-1250336792+z-990485-1677480024?_s=bm-mlbcom-hp
# https://www.mlbshop.com/caps/d-3494554436+z-921549-1032840697?_s=bm-mlbcom-hp
# https://www.mlbshop.com/men/ga-12+z-9112397524-3608394688?_s=bm-mlbcom-hp
# https://www.mlbshop.com/women/ga-57+z-822989763-3950492570?_s=bm-mlbcom-hp
# https://www.mlbshop.com/kids/ga-36+z-861270405-1171990865?_s=bm-mlbcom-hp
# https://www.mlbshop.com/big-and-tall/es-13+z-9534146835-2533870200?_s=bm-mlbcom-hp
# https://www.mlbshop.com/collectibles-and-memorabilia/d-7883550038+z-87646-4052890706?_s=bm-mlbcom-hp
# https://www.mlbshop.com/home-and-office/d-3449556733+z-992406-855732365?_s=bm-mlbcom-hp
# https://www.mlbshop.com/?os=1&_s=bm-mlbcom-hp
# https://www.mlbshop.com/gift-cards/x-462351+z-94899005-3509039474?_s=bm-mlbcom-Home
# https://www.mlb.com/wine
# https://photostore.mlb.com/
# http://www.mlbshopeurope.com/stores/mlb/en?portal=MLTS66FS&CMP=PSC-MLTS66FS
# http://www.mlbshopeurope.com/stores/mlb/en/c/jerseys?portal=MNNFEDPS&CMP=PSC-MNNFEDPS
# http://www.mlbshopeurope.com/stores/mlb/en/c/headwear?portal=XUIJ1QSB&CMP=PSC-XUIJ1QSB
# http://www.mlbshopeurope.com/stores/mlb/en/c/mens?portal=DS3U4BAJ&CMP=PSC-DS3U4BAJ
# http://www.mlbshopeurope.com/stores/mlb/en/c/womens?portal=CI2L2525&CMP=PSC-CI2L2525
# https://www.mlb.com/authentication
# http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&rc=25&selectedCatId=17342&sort=timeleft_asc&pgmode2=catpage
# http://www.baseballcards.mlb.com/
# http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&rc=25&selectedCatId=13020&sort=timeleft_asc&pgmode2=catpage
# http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&rc=25&selectedCatId=13041&sort=timeleft_asc&pgmode2=catpage
# http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&rc=25&selectedCatId=13021&sort=timeleft_asc&pgmode2=catpage
# https://www.mlb.com/mariners
# https://www.mlb.com/rangers
# https://www.mlb.com/braves
# https://www.mlb.com/marlins
# https://www.mlb.com/mets
# https://www.mlb.com/phillies
# https://www.mlb.com/nationals
# https://www.mlb.com/cubs
# https://www.mlb.com/reds
# https://www.mlb.com/brewers
# https://www.mlb.com/pirates
# https://www.mlb.com/cardinals
# https://www.mlb.com/dbacks
# https://www.mlb.com/rockies
# https://www.mlb.com/dodgers
# https://www.mlb.com/padres
# https://www.mlb.com/giants
# http://mlb.mlb.com/home
# http://mlb.mlb.com/home
# https://www.mlb.com/es
# http://www.mlb.jp/
# http://mlb.mbcsportsplus.com/
# #summary-block
# #stats-block
# #news-block
# #awards-block
# http://www.mlbshop.com/search/Sammy Sosa
# //twitter.com/mlb
# /video/first-last-sosa-s-home-runs-c2432509483
# /video/first-last-sosa-s-hits-c2432510483
# /video/mlb-now-cubs-2017-outlook-c1225226383
# https://www.mlb.com/video/search/tag/playerid-122544?displayName=Sammy Sosa
# #
# http://mlb.mlb.com/mlb/official_info/index.jsp
# http://mlb.mlb.com/mlb/official_info/about_mlb/
# http://mlb.mlb.com/mlb/official_info/about_mlb_com/
# https://www.mlb.com/team
# http://mlb.mlb.com/mlb/official_info/official_rules/official_rules.jsp
# http://m.mlb.com/official_rules/replay_review
# http://mlb.mlb.com/mlb/official_info/umpires/
# https://www.mlb.com/sponsorship
# https://www.mlb.com/news/topic/mlb-press-releases
# https://www.mlb.com/official-information/contact
# http://mlb.mlb.com/mlbtv/help-center/
# http://mlb.mlb.com/mlb/help/accessibility.jsp
# http://auctions.mlb.com/iSynApp/manageUserEmail!showEmailContactUsForm.action?sid=1101001
# http://mlb.mlb.com/mlb/help/faq_shop.jsp
# http://mlb.mlb.com/mlb/help/faq_tickets.jsp
# http://mlb.mlb.com/mlb/help/faq_alerts.jsp
# http://mlb.mlb.com/mlb/help/faq_dds.jsp
# http://mlb.mlb.com/mlb/help/faq_general_mlbcom.jsp
# http://mlbpaa.mlb.com/mlbpaa/index.jsp
# http://www.mlbplayers.com/
# https://www.milb.com/
# http://m.mlb.com/network
# http://www.tickets.com/
# http://web.yesnetwork.com/index.jsp
# https://www.sny.tv/
# http://web.theabl.com.au/index.jsp
# https://www.worldbaseballclassic.com/
# http://mlb.mlb.com/youthmajors/
# http://sabr.org/
# http://www.collegebaseballhall.org/index.jsp
# http://web.usabaseball.com/goldenspikes/
# http://web.usabaseball.com/index.jsp
# https://www.mlb.com/es/
# https://www.mlb.com/mlb-community
# https://www.mlb.com/all-star
# http://mlb.mlb.com/dr/
# http://mlb.mlb.com/mlb/kids/index.jsp
# https://photostore.mlb.com/
# http://mlb.mlb.com/mlb/events/winterleagues/
# http://web.usabaseball.com/playball/
# https://www.mlb.com/player-resource-center
# http://mlb.mlb.com/careers/index.jsp
# http://mlb.mlb.com/careers/boc/
# http://mlb.mlb.com/careers/mlbn/
# /
# https://www.bgca.org/about-us/our-partners/mlb
# https://www.facebook.com/mlb
# https://twitter.com/mlb
# https://www.instagram.com/mlb
# https://www.snapchat.com/add/mlb
# https://www.youtube.com/user/mlb
# https://www.pinterest.com/MLBOfficial/
# http://mlb.tumblr.com/
# https://securea.mlb.com/newsletters/?c_id=mlb
# https://www.reddit.com/user/mlbofficial
# https://www.mlb.com/official-information/terms-of-use
# https://www.mlb.com/official-information/privacy-policy
# http://mlb.mlb.com/mlb/official_info/about_mlb_com/legal_notices.jsp
# https://www.mlb.com/official-information/contact

# %% [markdown]
# ## Web Scraping Craigslist

# %%
titles = soup.findAll('a', {'class': 'result-title'})
 
for title in titles:
    print(title.text)
#Now, it will find all <a> tags whose class name is ‘result-title’.

# %%
addresses = soup.findAll('span', {'class': 'result-hood'})
 
for address in addresses:
   print(address.text)

# %%
from bs4 import BeautifulSoup
import requests
 
url = "https://boston.craigslist.org/search/sof"
 
# Getting the webpage, creating a Response object.
response = requests.get(url)
 
# Extracting the source code of the page.
data = response.text
 
# Passing the source code to Beautiful Soup to create a BeautifulSoup object for it.
soup = BeautifulSoup(data, 'lxml')
 
# Extracting all the <a> tags whose class name is 'result-title' into a list.
titles = soup.findAll('a', {'class': 'result-title'})
 
# Extracting text from the the <a> tags, i.e. class titles.
for title in titles:
    print(title.text)
# Out:
# Software Engineering Fellowship
# Data Engineer
# Sr. Database Admin. 10+ Month Contract (US Citizen or Greencard only)
# Android Technical Lead
# Autonomous Vehicle Operator | Toyota Research Institute
# Facilities Assistant
# Looking for Software Developers and Engineers
# Senior Application Developer
# Junior Engineer
# Autonomous Vehicle Operator | Toyota Research Institute
# Software Quality Assurance Engineer
# Product Owner
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Autonomous Vehicle Operator | Toyota Research Institute
# Software Engineering Fellowship
# Implementer for Software Company
# Python/Django Programmer
# Facilities Assistant
# Autonomous Vehicle Operator | Toyota Research Institute
# HR Coordinator- People Strategies
# Engineer, Process Validation
# Autonomous Vehicle Operator | Toyota Research Institute
# COBOL Instructors
# Senior GIS Analyst
# SWQA Engineer II
# Software Engineering Fellowship
# Autonomous Vehicle Operator | Toyota Research Institute
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Field Sales Engineer
# Clinical Content Developer
# Data, Research & Operations Specialist
# Autonomous Vehicle Operator | Toyota Research Institute
# Director of Project Management and Implementation
# Senior Developer/Analyst
# Data Architect/BI Developer
# Autonomous Vehicle Operator | Toyota Research Institute
# CRM Consultant
# .NET + Sage 50 Developer/Integrator
# RPG PROGRAMMER/DEVELOPER

# %%
#Using the same code to WebScrape a different URL
from bs4 import BeautifulSoup
import requests
 
url = "https://newyork.craigslist.org/d/software-qa-dba-etc/search/sof"
 
# Getting the webpage, creating a Response object.
response = requests.get(url)
 
# Extracting the source code of the page.
data = response.text
 
# Passing the source code to Beautiful Soup to create a BeautifulSoup object for it.
soup = BeautifulSoup(data, 'lxml')
 
# Extracting all the <a> tags whose class name is 'result-title' into a list.
titles = soup.findAll('a', {'class': 'result-title'})
 
# Extracting text from the the <a> tags, i.e. class titles.
for title in titles:
    print(title.text)
# Out:
# Web Developer
# Web Developer
# Sr Business Analyst w/Oracle EBS
# Senior Software Engineer
# Marketing Data Analyst | $22 - $25 per hour
# Serverless Application Engineer
# Product Management Fellowship
# Software Engineering Fellowship
# Senior Software Engineer
# Project Manager - for Dynamic SaaS Company
# Data Scientist with a rebellious spirit
# Ex-bike messenger(s) wanted to work in a software tech environment!
# Microsoft CRM Dynamics 365 Migration - full & part-time work from home
# Senior Backend Engineer
# Level 1 Operations Process Support (Connecticut)
# Senior QA Analyst – Long-term contract
# QA SDET Engineers  Needed - 3 Positions - All Levels
# Developers who want to learn about Hedge Funds, Private Equity, VC
# Data Analyst with  SQL   Financial
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Marketing Data Analyst | $22 - $25 per hour
# Product Management Fellowship
# Software Engineering Fellowship
# Quality assurance tester (Entry Level)
# Growing Company hiring Junior Devs and Senior Devs
# Implementer for Software Company
# QA Automation Engineer for Fortune Firm
# Paid Interview for Developers!
# BACKEND DEVELOPER Node.js, MongoDB, and MySQL
# Senior Marketing Data Analyst
# Full Stack Java Web Developer
# Sr. Full Stack Java Web Developer
# SMTP / POP3 / IMAP /
# 🔐 Keybase - Windows Frontend Engineer - Electron, FUSE, Golang
# Full Stack Developer (LAMP - PHP, MySql, JQuery, etc.)
# Marketing Data Analyst | $22 - $25 per hour
# Vice President, Software Infrastructure Developer
# COBOL Instructors
# Full Stack Web Developer
# Level 1 Operations Process Support (Connecticut)
# FT Healthcare Software Developer needed ASAP
# Product Management Fellowship
# Software Engineering Fellowship
# Marketing Data Analyst | $22 - $25 per hour
# Software Developer
# [!Kafka experience required!] Senior Software Engineer
# ⚙️ Back End Engineer (Bermi) - Python, to $200k, H-1B ok
# [React] Experienced Frontend Engineer - PINCHme
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# ERP Manager for Dynamic Software Company
# The Coder School Bayside General Manager
# Have a criminal record? Interested in tech? WE HAVE JOBS.
# Level 1 Operations Process Support (Connecticut)
# Senior Firmware
# Career Opportunity in IT for Immigrant Professionals
# Senior Back-end Engineer
# Sr. Java Developer
# Web Developer
# Full-stack Developer
# Marketing Data Analyst | $22 - $25 per hour
# Software Application Support Specialist
# Mac OS X
# SQL Programmer / Analyst
# Software Developer
# Electrical / Electro-Mechanical Designer
# MySQL Database Administrator (DBA) - Relocate to WashDC Area
# Entry level Software Engineer Developer
# Intern Web Application Programmer
# Web Application Developer Junior or Midrange
# Business Analyst
# IT Admin/ Support
# Client Relationship Specialist/Account Manager
# Entry level Software Developer
